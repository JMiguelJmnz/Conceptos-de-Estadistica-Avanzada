# %%
import numpy as np
import pandas as pd
import os

os.chdir("E:/EBAC/Material/M33-ConceptosAvanzadosdeEstadistica")
data = pd.read_csv("House Pricing.csv")
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data = data.fillna(0)
numeric_df = data.apply(pd.to_numeric, errors='coerce')
numeric_df = numeric_df.dropna(axis=1)
numeric_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
numeric_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    57.623288   10516.828082     6.099315
# std     421.610009    42.300571    34.664304    9981.264932     1.382997
# min       1.000000    20.000000     0.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    42.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    63.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    79.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.117123   443.639726  ...
# std       1.112799    30.202904     20.645407   180.731373   456.098091  ...
# ...

# %%
import dataprep.eda as eda
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import dataprep.eda as eda
#
# File ~\anaconda3\Lib\site-packages\dataprep\eda\__init__.py:9
#       6 from bokeh.io import output_notebook
#       8 from ..utils import is_notebook
# ----> 9 from .correlation import compute_correlation, plot_correlation, render_correlation
#      10 from .create_report import create_report
#      11 from .create_db_report import create_db_report
#
# File ~\anaconda3\Lib\site-packages\dataprep\eda\correlation\__init__.py:7
#       1 """
#       2     This module implements the plot_correlation(df) function.
#       3 """
#       5 from typing import Any, Dict, List, Optional, Tuple, Union
# ----> 7 import dask.dataframe as dd
#       8 import pandas as pd
#      10 from ..configs import Config
#
# File ~\anaconda3\Lib\site-packages\dask\dataframe\__init__.py:100
# ...

# %% [markdown]
# La variable que mas se relaciona con el precio de venta es la calidad general (OverallQual) con 79%

# %%
import statsmodels.api as sm

X = numeric_df.drop("SalePrice", axis=1)
y = numeric_df["SalePrice"]

# %%
X

# %%
y

# %%
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
print(model.summary())

# %% [markdown]
# Basandonos en el valor p, las variables mas significativas son
# MSSubClass
# LotArea
# OverallQual
# OverallCond
# YearBuilt
# MasVnrArea
# BsmtFinSF1
# TotalBsmtSF
# 1stFlrSF
# 2ndFlrSF
# GrLivArea
# BsmtFullBath
# BedroomAbvGr
# KitchenAbvGr
# TotRmsAbvGrd
# Fireplaces
# GarageYrBlt
# GarageCars
# WoodDeckSF
# ScreenPorch

# %%
valores_p = model.pvalues
variables_significativas = valores_p[valores_p < 0.05].index
var_sig = X[variables_significativas]
var_sig.head()

# %%
var_sig.describe()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
var_sig_con_constante = sm.add_constant(var_sig)

vif_data = pd.DataFrame()
vif_data["variable"] = var_sig_con_constante.columns
vif_data["VIF"] = [variance_inflation_factor(var_sig_con_constante.values, i) for i in range(var_sig_con_constante.shape[1])]

print(vif_data)

# %% [markdown]
# Las variables que presentan multi colinealidad, son 1stFlrSF, 2ndFlrSF, GrLivArea

# %%
X_filtrada = var_sig_con_constante.drop(["1stFlrSF", "2ndFlrSF", "GrLivArea"], axis=1)

model = sm.OLS(y, X_filtrada).fit()
print(model.summary())

# %% [markdown]
# Con todo el análisis anterior construye el modelo de regresión final excluyendo aquellas variables que consideres necesarias y mide el nivel de precisión del modelo por medio del error cuadratico medio y la R cuadrada. ¿Qué tan preciso fue tu modelo?

# %%
rss = sum((model.fittedvalues - y) ** 2)  
df_residual = len(y) - X.shape[1] 
mse = rss / df_residual
print(f'Error cuadratico medio (MSE): {mse}')

# %% [markdown]
# R-squared: 0.795  |  Adj. R-squared: 0.793
